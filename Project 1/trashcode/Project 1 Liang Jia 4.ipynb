# %%
import numpy as np
from sklearn.preprocessing import PolynomialFeatures

"""
    Linear regression using the Ridge method
"""

def RidgeRegression(x, y, z, degree=5, l=0.0001):
    """
    :param x: numpy vector of size (n, 1)
    :param y: numpy vector of size (n, 1)
    :param degree: degree of polynomial fit
    :param l: Ridge penalty coefficient
    :return: numpy array with the beta coefficients
    """
    # Calculate matrix with x, y - polynomials
    M_ = np.c_[x, y]
    poly = PolynomialFeatures(degree)
    M = poly.fit_transform(M_)



    # Calculate beta
    A = np.arange(1, degree + 2)
    rows = np.sum(A)
    beta = (np.linalg.inv(M.T.dot(M) + l * np.identity(rows))).dot(M.T).dot(z)

    return beta

# %%
"""
Functions to use in analysis of a regression method
"""
import numpy as np
from sklearn.preprocessing import PolynomialFeatures
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm

def FrankeFunction(x,y, noise=0.01):
    term1 = 0.75*np.exp(-(0.25*(9*x-2)**2) - 0.25*((9*y-2)**2))
    term2 = 0.75*np.exp(-((9*x+1)**2)/49.0 - 0.1*(9*y+1))
    term3 = 0.5*np.exp(-(9*x-7)**2/4.0 - 0.25*((9*y-3)**2))
    term4 = -0.2*np.exp(-(9*x-4)**2 - (9*y-7)**2)
    return (term1 + term2 + term3 + term4 + noise*np.random.randn(len(x)))

def R2(zReal, zPredicted):
    """
    :param zReal: actual z-values, size (n, 1)
    :param zPredicted: predicted z-values, size (n, 1)
    :return: R2-score
    """
    meanValue = np.mean(zReal)
    numerator = np.sum((zReal - zPredicted)**2)
    denominator = np.sum((zReal - meanValue)**2)
    result = 1 - (numerator/denominator)
    return result

def MeanSquaredError(z, z_hat):
    """
    :param z: actual z-values, size (n, 1)
    :param z_hat: predicted z-values, size (n, 1)
    :return: Mean squared error
    """
    MSE = np.sum((z - z_hat)**2)/len(z)
    return MSE

def betaConfidenceInterval_Ridge(z_real, beta, X, l):
    """
    Compute a 90% confidence interval for the beta coefficients - Ridge
    """

    # Calculate variance squared in the error
    z_hat = X.dot(beta)
    N, P = np.shape(X)
    sigma_2 = (np.sum(np.power((z_real-z_hat), 2)))/N

    # Calculate the variance squared of the beta coefficients
    XTX= X.T.dot(X)
    R, R = np.shape(XTX)
    var_beta = np.diag(sigma_2*np.linalg.inv((XTX + l*np.identity(R))))

    # The square root of var_beta is the standard error. Use it to calculate confidence intervals
    i_minus = beta - 1.645*np.sqrt(var_beta/N)
    i_plus = beta + 1.645*np.sqrt(var_beta/N)

    return i_minus, i_plus

def betaConfidenceInterval_OLS(z_real, beta, X):
    """
    Compute a 90% confidence interval for the beta coefficients
    """

    # Calculate variance squared in the error
    z_hat = X.dot(beta)
    N, P = np.shape(X)
    sigma_2 = (np.sum(np.power((z_real-z_hat), 2)))/N

    # Calculate the variance squared of the beta coefficients
    var_beta = np.diag(sigma_2*np.linalg.inv((X.T.dot(X))))

    # The square root of var_beta is the standard error. Use it to calculate confidence intervals
    i_minus = beta - 1.645*np.sqrt(var_beta/N)
    i_plus = beta + 1.645*np.sqrt(var_beta/N)

    return i_minus, i_plus

def plotFrankes(beta, degree=5):
    """
    Plot Franke's function
    """

    x = np.arange(0, 1, 0.01)
    y = np.arange(0, 1, 0.01)

    x_, y_ = np.meshgrid(x, y)
    x = x_.reshape(-1,1)
    y = y_.reshape(-1,1)

    M = np.c_[x, y]
    poly = PolynomialFeatures(degree=degree)
    M_ = poly.fit_transform(M)
    predict = M_.dot(beta)

    fig = plt.figure()
    ax = fig.gca(projection='3d')
    ax.plot_surface(x_, y_, predict.reshape(100, 100), cmap=cm.coolwarm, linewidth=0, antialiased=False)
    plt.show()

# %%
from sklearn.utils import resample
def bootstrap(x, y, z, p_degree, method, n_bootstrap=100):
    # Randomly shuffle data
    data_set = np.c_[x, y, z]
    np.random.shuffle(data_set)
    set_size = round(len(x)/5)

    # Extract test-set, never used in training. About 1/5 of total data
    x_test = data_set[0:set_size, 0]
    y_test = data_set[0:set_size, 1]
    z_test = data_set[0:set_size, 2]
    test_indices = np.linspace(0, set_size-1, set_size)

    # And define the training set as the rest of the data
    x_train = np.delete(data_set[:, 0], test_indices)
    y_train = np.delete(data_set[:, 1], test_indices)
    z_train = np.delete(data_set[:, 2], test_indices)

    Z_predict = []

    MSE = []
    R2s = []
    for i in range(n_bootstrap):
        x_, y_, z_ = resample(x_train, y_train, z_train)

        if method == 'Ridge':
            # Ridge regression, save beta values
            beta = RidgeRegression(x_, y_, z_, degree=p_degree)
        elif method == 'Lasso':
            beta = Lasso(x_, y_, z_, degree=p_degree)
        elif method == 'OLS':
            beta = ols(x_, y_, z_, degree=p_degree)
        else:
            print('ERROR: Cannot recognize method')
            return 0

        M_ = np.c_[x_test, y_test]
        poly = PolynomialFeatures(p_degree)
        M = poly.fit_transform(M_)
        z_hat = M.dot(beta)

        Z_predict.append(z_hat)

        # Calculate MSE
        MSE.append(np.mean((z_test - z_hat)**2))
        R2s.append(R2(z_test, z_hat))
        print('Round: ', i)

    # Calculate MSE, Bias and Variance
    MSE_M = np.mean(MSE)
    R2_M = np.mean(R2s)
    bias = np.mean((z_test - np.mean(Z_predict, axis=0, keepdims=True))**2)
    variance = np.mean(np.var(Z_predict, axis=0, keepdims=True))
    return MSE_M, R2_M, bias, variance

# %%
from sklearn.preprocessing import PolynomialFeatures
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
from mpl_toolkits.mplot3d import Axes3D

# %%
"""
Analysis of a Ridge Regression model of Franke's function, using set of 1000 random x and y points
"""
# Load random data, 1000 points
X = np.load('data.npy')
x = X[:, 0]
y = X[:, 1]

# Calculate Franke's function without noise
z = FrankeFunction(x, y, noise=0)

# %%
# Study dependence on lambdas
lambdas = [10**-7, 10**-6, 10**-5, 10**-4, 10**-3, 10**-2, 10**-1, 1]
lambdas_log = [-7, -6, -5, -4, -3, -2, -1, 0]

print('\nINVESTIGATE LAMBDAS')
Bs = []
for la in lambdas:
    Bs.append(RidgeRegression(x, y, z, l=la))

# Generate test data
x_test = np.random.rand(200)
y_test = np.random.rand(200)
z_test = FrankeFunction(x_test, y_test, noise=0)

# Calculate MSE, R2scores
M_ = np.c_[x_test, y_test]
poly5 = PolynomialFeatures(5)
M = poly5.fit_transform(M_)

MSEs = []
R2s = []
for i in range(len(lambdas)):
    z_predict = M.dot(Bs[i])
    MSE = MeanSquaredError(z_test, z_predict)
    MSEs.append(MSE)
    R2_score = R2(z_test, z_predict)
    R2s.append(R2_score)
    print('--- Lambda value: {0} ---\n Mean Squared error: {1:.7f} \n R2 Score: {2:.7f}\n'.format(lambdas[i], MSE, R2_score))
# Out:
# INVESTIGATE LAMBDAS
# --- Lambda value: 1e-07 ---
#  Mean Squared error: 0.0018027
#  R2 Score: 0.9776452
#
# --- Lambda value: 1e-06 ---
#  Mean Squared error: 0.0018011
#  R2 Score: 0.9776643
#
# --- Lambda value: 1e-05 ---
#  Mean Squared error: 0.0018164
#  R2 Score: 0.9774747
#
# --- Lambda value: 0.0001 ---
#  Mean Squared error: 0.0025059
#  R2 Score: 0.9689243
#
# --- Lambda value: 0.001 ---
#  Mean Squared error: 0.0041733
#  R2 Score: 0.9482478
#
# --- Lambda value: 0.01 ---
#  Mean Squared error: 0.0054733
#  R2 Score: 0.9321263
#
# --- Lambda value: 0.1 ---
#  Mean Squared error: 0.0082985
#  R2 Score: 0.8970911
#
# --- Lambda value: 1 ---
#  Mean Squared error: 0.0122727
#  R2 Score: 0.8478069

# %%
# Make figure
fig, ax1 = plt.subplots()
ax1.plot(lambdas_log, MSEs, 'bo-')
ax1.set_xlabel('Logarithmic lambda')
ax1.set_ylabel('MSE', color='b')
ax1.tick_params('y', colors='b')

ax2 = ax1.twinx()
ax2.plot(lambdas_log, R2s, 'r*-')
ax2.set_ylabel('R2 score', color='r')
ax2.tick_params('y', colors='r')

plt.grid(True)
plt.title('Influence of lambda on MSE and R2 Score')
fig.tight_layout()
plt.show()

# %%
# consider how the strength of noise affects the lambda values
noise = np.arange(0.001, 0.4, 0.005)
lambdas = [10**-5, 10**-4, 10**-3]
Bs = []

# Generate more data to test
x_test = np.random.rand(200)
y_test = np.random.rand(200)
M_ = np.c_[x_test, y_test]
poly5 = PolynomialFeatures(5)
M = poly5.fit_transform(M_)

for la in lambdas:
    B = []
    for n in noise:
        z = FrankeFunction(x, y, noise=n)
        B.append(RidgeRegression(x, y, z, l=la))
    Bs.append(B)

lines = []
plt.figure()
for i in range(len(lambdas)):
    print('--- lambda value:', lambdas[i], '--')
    line = []
    for j in range(len(noise)):
        z_test = FrankeFunction(x_test, y_test, noise=noise[j])
        z_predict = M.dot(Bs[i][j])
        MSE = MeanSquaredError(z_test, z_predict)
        line.append(MSE)
        R2_score = R2(z_test, z_predict)
        print(' Noise: {0} \n Mean Squared error: {1:.7f} \n R2 Score: {2:.7f}\n'.format(noise[j], MSE, R2_score))
    plt.plot(noise, line, label='Lambda = {0}'.format(lambdas[i]))

plt.legend()
plt.xlabel('D (Strength of noise)')
plt.ylabel('MSE')
plt.grid(True)
plt.title('Lambda and Noise')
plt.show()
# Out:
# --- lambda value: 1e-05 --
#  Noise: 0.001
#  Mean Squared error: 0.0019067
#  R2 Score: 0.9785861
#
#  Noise: 0.006
#  Mean Squared error: 0.0019938
#  R2 Score: 0.9776701
#
#  Noise: 0.011
#  Mean Squared error: 0.0020793
#  R2 Score: 0.9765812
#
#  Noise: 0.016
#  Mean Squared error: 0.0023470
#  R2 Score: 0.9737389
#
#  Noise: 0.021
#  Mean Squared error: 0.0023469
#  R2 Score: 0.9737976
#
#  Noise: 0.026000000000000002
#  Mean Squared error: 0.0024422
#  R2 Score: 0.9728667
#
#  Noise: 0.031
#  Mean Squared error: 0.0028947
#  R2 Score: 0.9666580
#
#  Noise: 0.036000000000000004
#  Mean Squared error: 0.0031439
#  R2 Score: 0.9652932
#
#  Noise: 0.041
#  Mean Squared error: 0.0032652
#  R2 Score: 0.9637618
#
#  Noise: 0.046
#  Mean Squared error: 0.0038947
#  R2 Score: 0.9580313
#
#  Noise: 0.051000000000000004
#  Mean Squared error: 0.0051154
#  R2 Score: 0.9440888
#
#  Noise: 0.056
#  Mean Squared error: 0.0054919
#  R2 Score: 0.9395374
#
#  Noise: 0.061
#  Mean Squared error: 0.0064550
#  R2 Score: 0.9327813
#
#  Noise: 0.066
#  Mean Squared error: 0.0057401
#  R2 Score: 0.9377390
#
#  Noise: 0.07100000000000001
#  Mean Squared error: 0.0064743
#  R2 Score: 0.9279689
#
#  Noise: 0.076
#  Mean Squared error: 0.0074887
#  R2 Score: 0.9185324
#
#  Noise: 0.081
#  Mean Squared error: 0.0077398
#  R2 Score: 0.9138070
#
#  Noise: 0.08600000000000001
#  Mean Squared error: 0.0096102
#  R2 Score: 0.9000613
#
#  Noise: 0.091
#  Mean Squared error: 0.0104541
#  R2 Score: 0.8961700
#
#  Noise: 0.096
#  Mean Squared error: 0.0096243
#  R2 Score: 0.8975451
#
#  Noise: 0.101
#  Mean Squared error: 0.0124923
#  R2 Score: 0.8772503
#
#  Noise: 0.106
#  Mean Squared error: 0.0125334
#  R2 Score: 0.8704057
#
#  Noise: 0.111
#  Mean Squared error: 0.0140037
#  R2 Score: 0.8559009
#
#  Noise: 0.116
#  Mean Squared error: 0.0153102
#  R2 Score: 0.8404863
#
#  Noise: 0.121
#  Mean Squared error: 0.0171377
#  R2 Score: 0.8178381
#
#  Noise: 0.126
#  Mean Squared error: 0.0159689
#  R2 Score: 0.8204316
#
#  Noise: 0.131
#  Mean Squared error: 0.0193728
#  R2 Score: 0.8280528
#
#  Noise: 0.136
#  Mean Squared error: 0.0197497
#  R2 Score: 0.8128311
#
#  Noise: 0.14100000000000001
#  Mean Squared error: 0.0237689
#  R2 Score: 0.7653200
#
#  Noise: 0.146
#  Mean Squared error: 0.0237984
#  R2 Score: 0.7805903
#
#  Noise: 0.151
#  Mean Squared error: 0.0272575
#  R2 Score: 0.7536482
#
#  Noise: 0.156
#  Mean Squared error: 0.0307025
#  R2 Score: 0.7208794
#
#  Noise: 0.161
#  Mean Squared error: 0.0330921
#  R2 Score: 0.7125006
#
#  Noise: 0.166
#  Mean Squared error: 0.0333654
#  R2 Score: 0.7243257
#
#  Noise: 0.171
#  Mean Squared error: 0.0329091
#  R2 Score: 0.7309147
#
#  Noise: 0.17600000000000002
#  Mean Squared error: 0.0308168
#  R2 Score: 0.7299532
#
#  Noise: 0.181
#  Mean Squared error: 0.0408425
#  R2 Score: 0.6786826
#
#  Noise: 0.186
#  Mean Squared error: 0.0358731
#  R2 Score: 0.7256195
#
#  Noise: 0.191
#  Mean Squared error: 0.0423694
#  R2 Score: 0.6677235
#
#  Noise: 0.196
#  Mean Squared error: 0.0345418
#  R2 Score: 0.6777222
#
#  Noise: 0.201
#  Mean Squared error: 0.0409641
#  R2 Score: 0.6922276
#
#  Noise: 0.20600000000000002
#  Mean Squared error: 0.0402797
#  R2 Score: 0.6710774
#
#  Noise: 0.211
#  Mean Squared error: 0.0434133
#  R2 Score: 0.6818346
#
#  Noise: 0.216
#  Mean Squared error: 0.0494270
#  R2 Score: 0.5721669
#
#  Noise: 0.221
#  Mean Squared error: 0.0515220
#  R2 Score: 0.6515835
#
#  Noise: 0.226
#  Mean Squared error: 0.0481409
#  R2 Score: 0.6493969
#
#  Noise: 0.231
#  Mean Squared error: 0.0580825
#  R2 Score: 0.5858208
#
#  Noise: 0.23600000000000002
#  Mean Squared error: 0.0539049
#  R2 Score: 0.6274744
#
#  Noise: 0.241
#  Mean Squared error: 0.0658023
#  R2 Score: 0.5923540
#
#  Noise: 0.246
#  Mean Squared error: 0.0642459
#  R2 Score: 0.5832385
#
#  Noise: 0.251
#  Mean Squared error: 0.0625919
#  R2 Score: 0.5867671
#
#  Noise: 0.256
#  Mean Squared error: 0.0806647
#  R2 Score: 0.4926349
#
#  Noise: 0.261
#  Mean Squared error: 0.0651866
#  R2 Score: 0.6013580
#
#  Noise: 0.266
#  Mean Squared error: 0.0708031
#  R2 Score: 0.5112881
#
#  Noise: 0.271
#  Mean Squared error: 0.0816783
#  R2 Score: 0.5002884
#
#  Noise: 0.276
#  Mean Squared error: 0.0747999
#  R2 Score: 0.4826125
#
#  Noise: 0.281
#  Mean Squared error: 0.0757865
#  R2 Score: 0.5403871
#
#  Noise: 0.28600000000000003
#  Mean Squared error: 0.0905185
#  R2 Score: 0.4790229
#
#  Noise: 0.291
#  Mean Squared error: 0.0885921
#  R2 Score: 0.5149387
#
#  Noise: 0.296
#  Mean Squared error: 0.0960141
#  R2 Score: 0.5256599
#
#  Noise: 0.301
#  Mean Squared error: 0.0818314
#  R2 Score: 0.4481166
#
#  Noise: 0.306
#  Mean Squared error: 0.1283632
#  R2 Score: 0.4685101
#
#  Noise: 0.311
#  Mean Squared error: 0.1104832
#  R2 Score: 0.4286464
#
#  Noise: 0.316
#  Mean Squared error: 0.1078897
#  R2 Score: 0.5031547
#
#  Noise: 0.321
#  Mean Squared error: 0.0945496
#  R2 Score: 0.4799976
#
#  Noise: 0.326
#  Mean Squared error: 0.1154666
#  R2 Score: 0.4787697
#
#  Noise: 0.331
#  Mean Squared error: 0.1204403
#  R2 Score: 0.4734733
#
#  Noise: 0.336
#  Mean Squared error: 0.0969240
#  R2 Score: 0.4928385
#
#  Noise: 0.341
#  Mean Squared error: 0.1165405
#  R2 Score: 0.4662175
#
#  Noise: 0.34600000000000003
#  Mean Squared error: 0.1065694
#  R2 Score: 0.4388512
#
#  Noise: 0.35100000000000003
#  Mean Squared error: 0.1562273
#  R2 Score: 0.4000767
#
#  Noise: 0.356
#  Mean Squared error: 0.1284805
#  R2 Score: 0.3828938
#
#  Noise: 0.361
#  Mean Squared error: 0.1295146
#  R2 Score: 0.4492168
#
#  Noise: 0.366
#  Mean Squared error: 0.1478769
#  R2 Score: 0.3935321
#
#  Noise: 0.371
#  Mean Squared error: 0.1453335
#  R2 Score: 0.3667013
#
#  Noise: 0.376
#  Mean Squared error: 0.1470092
#  R2 Score: 0.3880290
#
#  Noise: 0.381
#  Mean Squared error: 0.1627591
#  R2 Score: 0.4107988
#
#  Noise: 0.386
#  Mean Squared error: 0.1494171
#  R2 Score: 0.4041503
#
#  Noise: 0.391
#  Mean Squared error: 0.1706730
#  R2 Score: 0.2311611
#
#  Noise: 0.396
#  Mean Squared error: 0.1634638
#  R2 Score: 0.3083726
#
# --- lambda value: 0.0001 --
#  Noise: 0.001
#  Mean Squared error: 0.0021754
#  R2 Score: 0.9755760
#
#  Noise: 0.006
#  Mean Squared error: 0.0021920
#  R2 Score: 0.9753900
#
#  Noise: 0.011
#  Mean Squared error: 0.0022276
#  R2 Score: 0.9750152
#
#  Noise: 0.016
#  Mean Squared error: 0.0023608
#  R2 Score: 0.9735852
#
#  Noise: 0.021
#  Mean Squared error: 0.0025872
#  R2 Score: 0.9709513
#
#  Noise: 0.026000000000000002
#  Mean Squared error: 0.0027967
#  R2 Score: 0.9692349
#
#  Noise: 0.031
#  Mean Squared error: 0.0032947
#  R2 Score: 0.9639110
#
#  Noise: 0.036000000000000004
#  Mean Squared error: 0.0033882
#  R2 Score: 0.9621848
#
#  Noise: 0.041
#  Mean Squared error: 0.0041007
#  R2 Score: 0.9557195
#
#  Noise: 0.046
#  Mean Squared error: 0.0041131
#  R2 Score: 0.9549103
#
#  Noise: 0.051000000000000004
#  Mean Squared error: 0.0046133
#  R2 Score: 0.9492923
#
#  Noise: 0.056
#  Mean Squared error: 0.0054453
#  R2 Score: 0.9369639
#
#  Noise: 0.061
#  Mean Squared error: 0.0062115
#  R2 Score: 0.9298846
#
#  Noise: 0.066
#  Mean Squared error: 0.0071440
#  R2 Score: 0.9239574
#
#  Noise: 0.07100000000000001
#  Mean Squared error: 0.0069214
#  R2 Score: 0.9250247
#
#  Noise: 0.076
#  Mean Squared error: 0.0078360
#  R2 Score: 0.9177537
#
#  Noise: 0.081
#  Mean Squared error: 0.0094547
#  R2 Score: 0.9034022
#
#  Noise: 0.08600000000000001
#  Mean Squared error: 0.0101438
#  R2 Score: 0.8987851
#
#  Noise: 0.091
#  Mean Squared error: 0.0106615
#  R2 Score: 0.8951488
#
#  Noise: 0.096
#  Mean Squared error: 0.0118980
#  R2 Score: 0.8789210
#
#  Noise: 0.101
#  Mean Squared error: 0.0113542
#  R2 Score: 0.8874696
#
#  Noise: 0.106
#  Mean Squared error: 0.0152410
#  R2 Score: 0.8461419
#
#  Noise: 0.111
#  Mean Squared error: 0.0173310
#  R2 Score: 0.8253260
#
#  Noise: 0.116
#  Mean Squared error: 0.0153830
#  R2 Score: 0.8430900
#
#  Noise: 0.121
#  Mean Squared error: 0.0159408
#  R2 Score: 0.8417631
#
#  Noise: 0.126
#  Mean Squared error: 0.0202702
#  R2 Score: 0.8118264
#
#  Noise: 0.131
#  Mean Squared error: 0.0210990
#  R2 Score: 0.7938629
#
#  Noise: 0.136
#  Mean Squared error: 0.0214275
#  R2 Score: 0.8062012
#
#  Noise: 0.14100000000000001
#  Mean Squared error: 0.0201727
#  R2 Score: 0.7762892
#
#  Noise: 0.146
#  Mean Squared error: 0.0216331
#  R2 Score: 0.7943067
#
#  Noise: 0.151
#  Mean Squared error: 0.0269884
#  R2 Score: 0.7507228
#
#  Noise: 0.156
#  Mean Squared error: 0.0303620
#  R2 Score: 0.7477394
#
#  Noise: 0.161
#  Mean Squared error: 0.0289098
#  R2 Score: 0.7520526
#
#  Noise: 0.166
#  Mean Squared error: 0.0319756
#  R2 Score: 0.7389255
#
#  Noise: 0.171
#  Mean Squared error: 0.0318384
#  R2 Score: 0.7140939
#
#  Noise: 0.17600000000000002
#  Mean Squared error: 0.0338023
#  R2 Score: 0.7130471
#
#  Noise: 0.181
#  Mean Squared error: 0.0387950
#  R2 Score: 0.6772331
#
#  Noise: 0.186
#  Mean Squared error: 0.0333011
#  R2 Score: 0.7006008
#
#  Noise: 0.191
#  Mean Squared error: 0.0423087
#  R2 Score: 0.6517652
#
#  Noise: 0.196
#  Mean Squared error: 0.0427447
#  R2 Score: 0.6047275
#
#  Noise: 0.201
#  Mean Squared error: 0.0450913
#  R2 Score: 0.6513382
#
#  Noise: 0.20600000000000002
#  Mean Squared error: 0.0527374
#  R2 Score: 0.6420317
#
#  Noise: 0.211
#  Mean Squared error: 0.0394071
#  R2 Score: 0.6968729
#
#  Noise: 0.216
#  Mean Squared error: 0.0525287
#  R2 Score: 0.6297653
#
#  Noise: 0.221
#  Mean Squared error: 0.0449316
#  R2 Score: 0.6854520
#
#  Noise: 0.226
#  Mean Squared error: 0.0579352
#  R2 Score: 0.6062695
#
#  Noise: 0.231
#  Mean Squared error: 0.0527120
#  R2 Score: 0.6402253
#
#  Noise: 0.23600000000000002
#  Mean Squared error: 0.0553737
#  R2 Score: 0.5452834
#
#  Noise: 0.241
#  Mean Squared error: 0.0616811
#  R2 Score: 0.5787534
#
#  Noise: 0.246
#  Mean Squared error: 0.0762460
#  R2 Score: 0.5059639
#
#  Noise: 0.251
#  Mean Squared error: 0.0603323
#  R2 Score: 0.5964945
#
#  Noise: 0.256
#  Mean Squared error: 0.0624276
#  R2 Score: 0.5866283
#
#  Noise: 0.261
#  Mean Squared error: 0.0551718
#  R2 Score: 0.6361116
#
#  Noise: 0.266
#  Mean Squared error: 0.0713490
#  R2 Score: 0.5416632
#
#  Noise: 0.271
#  Mean Squared error: 0.0840534
#  R2 Score: 0.5260753
#
#  Noise: 0.276
#  Mean Squared error: 0.0901939
#  R2 Score: 0.5344759
#
#  Noise: 0.281
#  Mean Squared error: 0.0814899
#  R2 Score: 0.4212748
#
#  Noise: 0.28600000000000003
#  Mean Squared error: 0.0830179
#  R2 Score: 0.4612638
#
#  Noise: 0.291
#  Mean Squared error: 0.0807432
#  R2 Score: 0.5490305
#
#  Noise: 0.296
#  Mean Squared error: 0.0840003
#  R2 Score: 0.5670066
#
#  Noise: 0.301
#  Mean Squared error: 0.1012988
#  R2 Score: 0.3741947
#
#  Noise: 0.306
#  Mean Squared error: 0.0895146
#  R2 Score: 0.5225202
#
#  Noise: 0.311
#  Mean Squared error: 0.1103150
#  R2 Score: 0.4192789
#
#  Noise: 0.316
#  Mean Squared error: 0.1254214
#  R2 Score: 0.3818630
#
#  Noise: 0.321
#  Mean Squared error: 0.1164336
#  R2 Score: 0.4020718
#
#  Noise: 0.326
#  Mean Squared error: 0.0815371
#  R2 Score: 0.5397346
#
#  Noise: 0.331
#  Mean Squared error: 0.1036118
#  R2 Score: 0.4890145
#
#  Noise: 0.336
#  Mean Squared error: 0.1128292
#  R2 Score: 0.4631979
#
#  Noise: 0.341
#  Mean Squared error: 0.1320099
#  R2 Score: 0.3902336
#
#  Noise: 0.34600000000000003
#  Mean Squared error: 0.1192481
#  R2 Score: 0.3904149
#
#  Noise: 0.35100000000000003
#  Mean Squared error: 0.1283524
#  R2 Score: 0.4066347
#
#  Noise: 0.356
#  Mean Squared error: 0.1331353
#  R2 Score: 0.4063861
#
#  Noise: 0.361
#  Mean Squared error: 0.1193358
#  R2 Score: 0.4141771
#
#  Noise: 0.366
#  Mean Squared error: 0.1425376
#  R2 Score: 0.4214455
#
#  Noise: 0.371
#  Mean Squared error: 0.1457131
#  R2 Score: 0.4440866
#
#  Noise: 0.376
#  Mean Squared error: 0.1368342
#  R2 Score: 0.3474600
#
#  Noise: 0.381
#  Mean Squared error: 0.1387716
#  R2 Score: 0.3382376
#
#  Noise: 0.386
#  Mean Squared error: 0.1448806
#  R2 Score: 0.3219689
#
#  Noise: 0.391
#  Mean Squared error: 0.1702347
#  R2 Score: 0.3471995
#
#  Noise: 0.396
#  Mean Squared error: 0.1918634
#  R2 Score: 0.2999203
#
# --- lambda value: 0.001 --
#  Noise: 0.001
#  Mean Squared error: 0.0033866
#  R2 Score: 0.9619900
#
#  Noise: 0.006
#  Mean Squared error: 0.0034235
#  R2 Score: 0.9614002
#
#  Noise: 0.011
#  Mean Squared error: 0.0033902
#  R2 Score: 0.9618771
#
#  Noise: 0.016
#  Mean Squared error: 0.0034507
#  R2 Score: 0.9616703
#
#  Noise: 0.021
#  Mean Squared error: 0.0035962
#  R2 Score: 0.9593794
#
#  Noise: 0.026000000000000002
#  Mean Squared error: 0.0042544
#  R2 Score: 0.9529991
#
#  Noise: 0.031
#  Mean Squared error: 0.0041856
#  R2 Score: 0.9532822
#
#  Noise: 0.036000000000000004
#  Mean Squared error: 0.0043779
#  R2 Score: 0.9510644
#
#  Noise: 0.041
#  Mean Squared error: 0.0050737
#  R2 Score: 0.9452656
#
#  Noise: 0.046
#  Mean Squared error: 0.0053429
#  R2 Score: 0.9379118
#
#  Noise: 0.051000000000000004
#  Mean Squared error: 0.0063276
#  R2 Score: 0.9315502
#
#  Noise: 0.056
#  Mean Squared error: 0.0069760
#  R2 Score: 0.9260080
#
#  Noise: 0.061
#  Mean Squared error: 0.0070406
#  R2 Score: 0.9241649
#
#  Noise: 0.066
#  Mean Squared error: 0.0079638
#  R2 Score: 0.9169474
#
#  Noise: 0.07100000000000001
#  Mean Squared error: 0.0087994
#  R2 Score: 0.9085473
#
#  Noise: 0.076
#  Mean Squared error: 0.0081392
#  R2 Score: 0.9144274
#
#  Noise: 0.081
#  Mean Squared error: 0.0081332
#  R2 Score: 0.9117869
#
#  Noise: 0.08600000000000001
#  Mean Squared error: 0.0087874
#  R2 Score: 0.9024998
#
#  Noise: 0.091
#  Mean Squared error: 0.0151792
#  R2 Score: 0.8554177
#
#  Noise: 0.096
#  Mean Squared error: 0.0135917
#  R2 Score: 0.8565093
#
#  Noise: 0.101
#  Mean Squared error: 0.0139001
#  R2 Score: 0.8593398
#
#  Noise: 0.106
#  Mean Squared error: 0.0168568
#  R2 Score: 0.8348668
#
#  Noise: 0.111
#  Mean Squared error: 0.0152947
#  R2 Score: 0.8509301
#
#  Noise: 0.116
#  Mean Squared error: 0.0154214
#  R2 Score: 0.8555311
#
#  Noise: 0.121
#  Mean Squared error: 0.0200411
#  R2 Score: 0.8207841
#
#  Noise: 0.126
#  Mean Squared error: 0.0227719
#  R2 Score: 0.7978269
#
#  Noise: 0.131
#  Mean Squared error: 0.0205866
#  R2 Score: 0.8059745
#
#  Noise: 0.136
#  Mean Squared error: 0.0191517
#  R2 Score: 0.8191784
#
#  Noise: 0.14100000000000001
#  Mean Squared error: 0.0225796
#  R2 Score: 0.7870892
#
#  Noise: 0.146
#  Mean Squared error: 0.0249830
#  R2 Score: 0.7653587
#
#  Noise: 0.151
#  Mean Squared error: 0.0308078
#  R2 Score: 0.7375131
#
#  Noise: 0.156
#  Mean Squared error: 0.0328601
#  R2 Score: 0.7364825
#
#  Noise: 0.161
#  Mean Squared error: 0.0302798
#  R2 Score: 0.7015360
#
#  Noise: 0.166
#  Mean Squared error: 0.0398659
#  R2 Score: 0.6884686
#
#  Noise: 0.171
#  Mean Squared error: 0.0320766
#  R2 Score: 0.7042909
#
#  Noise: 0.17600000000000002
#  Mean Squared error: 0.0317216
#  R2 Score: 0.7406808
#
#  Noise: 0.181
#  Mean Squared error: 0.0320625
#  R2 Score: 0.7161139
#
#  Noise: 0.186
#  Mean Squared error: 0.0391905
#  R2 Score: 0.7097556
#
#  Noise: 0.191
#  Mean Squared error: 0.0380462
#  R2 Score: 0.7040170
#
#  Noise: 0.196
#  Mean Squared error: 0.0360523
#  R2 Score: 0.7087144
#
#  Noise: 0.201
#  Mean Squared error: 0.0431331
#  R2 Score: 0.6672496
#
#  Noise: 0.20600000000000002
#  Mean Squared error: 0.0450389
#  R2 Score: 0.6352780
#
#  Noise: 0.211
#  Mean Squared error: 0.0441161
#  R2 Score: 0.6717718
#
#  Noise: 0.216
#  Mean Squared error: 0.0562605
#  R2 Score: 0.6169998
#
#  Noise: 0.221
#  Mean Squared error: 0.0630016
#  R2 Score: 0.6098381
#
#  Noise: 0.226
#  Mean Squared error: 0.0532652
#  R2 Score: 0.6041728
#
#  Noise: 0.231
#  Mean Squared error: 0.0592265
#  R2 Score: 0.5620071
#
#  Noise: 0.23600000000000002
#  Mean Squared error: 0.0619253
#  R2 Score: 0.5997287
#
#  Noise: 0.241
#  Mean Squared error: 0.0679756
#  R2 Score: 0.5777819
#
#  Noise: 0.246
#  Mean Squared error: 0.0674742
#  R2 Score: 0.5275465
#
#  Noise: 0.251
#  Mean Squared error: 0.0662031
#  R2 Score: 0.5250318
#
#  Noise: 0.256
#  Mean Squared error: 0.0684356
#  R2 Score: 0.4881721
#
#  Noise: 0.261
#  Mean Squared error: 0.0780220
#  R2 Score: 0.4894269
#
#  Noise: 0.266
#  Mean Squared error: 0.0740412
#  R2 Score: 0.5555006
#
#  Noise: 0.271
#  Mean Squared error: 0.0750956
#  R2 Score: 0.4996539
#
#  Noise: 0.276
#  Mean Squared error: 0.0765881
#  R2 Score: 0.5375444
#
#  Noise: 0.281
#  Mean Squared error: 0.0798193
#  R2 Score: 0.4783210
#
#  Noise: 0.28600000000000003
#  Mean Squared error: 0.0889826
#  R2 Score: 0.4950455
#
#  Noise: 0.291
#  Mean Squared error: 0.0786304
#  R2 Score: 0.5196479
#
#  Noise: 0.296
#  Mean Squared error: 0.0858983
#  R2 Score: 0.4876828
#
#  Noise: 0.301
#  Mean Squared error: 0.1024759
#  R2 Score: 0.2998237
#
#  Noise: 0.306
#  Mean Squared error: 0.0961759
#  R2 Score: 0.4853251
#
#  Noise: 0.311
#  Mean Squared error: 0.0989348
#  R2 Score: 0.4649394
#
#  Noise: 0.316
#  Mean Squared error: 0.0965833
#  R2 Score: 0.4013279
#
#  Noise: 0.321
#  Mean Squared error: 0.0862078
#  R2 Score: 0.4721670
#
#  Noise: 0.326
#  Mean Squared error: 0.1093225
#  R2 Score: 0.5102025
#
#  Noise: 0.331
#  Mean Squared error: 0.1048471
#  R2 Score: 0.4209688
#
#  Noise: 0.336
#  Mean Squared error: 0.1096900
#  R2 Score: 0.4701603
#
#  Noise: 0.341
#  Mean Squared error: 0.1258937
#  R2 Score: 0.4215462
#
#  Noise: 0.34600000000000003
#  Mean Squared error: 0.1443621
#  R2 Score: 0.3305001
#
#  Noise: 0.35100000000000003
#  Mean Squared error: 0.1239960
#  R2 Score: 0.4342169
#
#  Noise: 0.356
#  Mean Squared error: 0.1217976
#  R2 Score: 0.3836783
#
#  Noise: 0.361
#  Mean Squared error: 0.1329643
#  R2 Score: 0.3712484
#
#  Noise: 0.366
#  Mean Squared error: 0.1270293
#  R2 Score: 0.4587018
#
#  Noise: 0.371
#  Mean Squared error: 0.1724996
#  R2 Score: 0.3354751
#
#  Noise: 0.376
#  Mean Squared error: 0.1667300
#  R2 Score: 0.3066066
#
#  Noise: 0.381
#  Mean Squared error: 0.1682866
#  R2 Score: 0.3317474
#
#  Noise: 0.386
#  Mean Squared error: 0.1544515
#  R2 Score: 0.3134873
#
#  Noise: 0.391
#  Mean Squared error: 0.1913245
#  R2 Score: 0.2706427
#
#  Noise: 0.396
#  Mean Squared error: 0.1639260
#  R2 Score: 0.3240855

# %%
# Find the beta confidence intervals
# Load random data, 1000 points
X = np.load('data.npy')
x = X[:, 0]
y = X[:, 1]

# Calculate Franke's function
z = FrankeFunction(x, y, noise=0.1)

# Generate test data
x_test = np.random.rand(1000)
y_test = np.random.rand(1000)
z_test = FrankeFunction(x_test, y_test, noise=0.1)

# Calculate beta values and polynomial matrix
beta = RidgeRegression(x, y, z, degree=5, l=10**-4)
M_ = np.c_[x_test, y_test]
poly5 = PolynomialFeatures(5)
M = poly5.fit_transform(M_)

# Calculate beta confidence intervals
conf1, conf2 = betaConfidenceInterval_Ridge(z_test, beta, M, l=10**-4)

for i in range(len(conf1)):
    print('Beta {0}: {1:5f} & [{2:5f}, {3:5f}]'.format(i, beta[i], conf1[i], conf2[i]))
# Out:
# Beta 0: 0.604864 & [0.601936, 0.607792]
# Beta 1: 5.699332 & [5.671688, 5.726977]
# Beta 2: 2.711019 & [2.682320, 2.739718]
# Beta 3: -25.028707 & [-25.152944, -24.904471]
# Beta 4: -7.005152 & [-7.111104, -6.899199]
# Beta 5: -8.386169 & [-8.509970, -8.262368]
# Beta 6: 28.755989 & [28.486042, 29.025935]
# Beta 7: 29.233365 & [29.007505, 29.459226]
# Beta 8: 5.426303 & [5.197363, 5.655242]
# Beta 9: -1.392691 & [-1.660308, -1.125075]
# Beta 10: -4.668165 & [-4.951474, -4.384856]
# Beta 11: -38.328831 & [-38.584980, -38.072682]
# Beta 12: 4.860350 & [4.626526, 5.094173]
# Beta 13: -16.314996 & [-16.568938, -16.061054]
# Beta 14: 17.430680 & [17.147453, 17.713907]
# Beta 15: -5.341778 & [-5.456527, -5.227029]
# Beta 16: 12.821391 & [12.700405, 12.942376]
# Beta 17: 7.864268 & [7.746053, 7.982483]
# Beta 18: -11.292181 & [-11.411597, -11.172764]
# Beta 19: 13.102378 & [12.983756, 13.221000]
# Beta 20: -10.837209 & [-10.952372, -10.722045]

# %%
# Use bootstrap algorithm to estimate MSE, R2, bias and variance
X = np.load('data.npy')
x = X[:, 0]
y = X[:, 1]
z = FrankeFunction(x, y, noise=0.1)

MSE, R2_b, bias, variance = bootstrap(x, y, z, method='Ridge', p_degree=5)
print('--- BOOTSTRAP ---')
print('MSE: ', MSE)
print('R2: ', R2_b)
print('Bias: ', bias)
print('Variance: ', variance)
# Out:
# Round:  0
# Round:  1
# Round:  2
# Round:  3
# Round:  4
# Round:  5
# Round:  6
# Round:  7
# Round:  8
# Round:  9
# Round:  10
# Round:  11
# Round:  12
# Round:  13
# Round:  14
# Round:  15
# Round:  16
# Round:  17
# Round:  18
# Round:  19
# Round:  20
# Round:  21
# Round:  22
# Round:  23
# Round:  24
# Round:  25
# Round:  26
# Round:  27
# Round:  28
# Round:  29
# Round:  30
# Round:  31
# Round:  32
# Round:  33
# Round:  34
# Round:  35
# Round:  36
# Round:  37
# Round:  38
# Round:  39
# Round:  40
# Round:  41
# Round:  42
# Round:  43
# Round:  44
# Round:  45
# Round:  46
# Round:  47
# Round:  48
# Round:  49
# Round:  50
# Round:  51
# Round:  52
# Round:  53
# Round:  54
# Round:  55
# Round:  56
# Round:  57
# Round:  58
# Round:  59
# Round:  60
# Round:  61
# Round:  62
# Round:  63
# Round:  64
# Round:  65
# Round:  66
# Round:  67
# Round:  68
# Round:  69
# Round:  70
# Round:  71
# Round:  72
# Round:  73
# Round:  74
# Round:  75
# Round:  76
# Round:  77
# Round:  78
# Round:  79
# Round:  80
# Round:  81
# Round:  82
# Round:  83
# Round:  84
# Round:  85
# Round:  86
# Round:  87
# Round:  88
# Round:  89
# Round:  90
# Round:  91
# Round:  92
# Round:  93
# Round:  94
# Round:  95
# Round:  96
# Round:  97
# Round:  98
# Round:  99
# --- BOOTSTRAP ---
# MSE:  0.012073235742748455
# R2:  0.8585590345917634
# Bias:  0.011783095827828358
# Variance:  0.0002901399149200989
# C:\Users\bod\anaconda3\lib\site-packages\ipykernel_launcher.py:15: DeprecationWarning: using a non-integer array as obj in delete will result in an error in the future
#   from ipykernel import kernelapp as app
# C:\Users\bod\anaconda3\lib\site-packages\ipykernel_launcher.py:16: DeprecationWarning: using a non-integer array as obj in delete will result in an error in the future
#   app.launch_new_instance()
# C:\Users\bod\anaconda3\lib\site-packages\ipykernel_launcher.py:17: DeprecationWarning: using a non-integer array as obj in delete will result in an error in the future

# %%
"""
Functions to use in analysis of a regression method
"""
import numpy as np
from sklearn.preprocessing import PolynomialFeatures
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
from sklearn.utils import resample

def FrankeFunction(x,y, noise = 0):
    term1 = 0.75*np.exp(-(0.25*(9*x-2)**2) - 0.25*((9*y-2)**2))
    term2 = 0.75*np.exp(-((9*x+1)**2)/49.0 - 0.1*(9*y+1))
    term3 = 0.5*np.exp(-(9*x-7)**2/4.0 - 0.25*((9*y-3)**2))
    term4 = -0.2*np.exp(-(9*x-4)**2 - (9*y-7)**2)
    return (term1 + term2 + term3 + term4 + noise*np.random.randn(len(x)))


def R2(zReal, zPredicted):
    """
    :param zReal: actual z-values, size (n, 1)
    :param zPredicted: predicted z-values, size (n, 1)
    :return: R2-score
    """
    meanValue = np.mean(zReal)
    numerator = np.sum((zReal - zPredicted)**2)
    denominator = np.sum((zReal - meanValue)**2)
    result = 1 - (numerator/denominator)
    return result

def MeanSquaredError(z, z_hat):
    """
    :param z: actual z-values, size (n, 1)
    :param z_hat: predicted z-values, size (n, 1)
    :return: Mean squared error
    """
    MSE = np.sum((z - z_hat)**2)/len(z)
    return MSE

def betaCI_OLS(z_real, beta, X):
    """
    Compute a 90% confidence interval for the beta coefficients
    """

    # Calculate variance squared in the error
    z_hat = X.dot(beta)
    N, P = np.shape(X)
    sigma2 = (np.sum(np.power((z_real-z_hat), 2)))/N

    # Calculate the variance squared of the beta coefficients
    var_beta = np.diag(sigma2*np.linalg.inv((X.T.dot(X))))

    # The square root of var_beta is the standard error. Use it to calculate confidence intervals
    ci_minus = beta - 1.645*np.sqrt(var_beta/N)
    ci_plus = beta + 1.645*np.sqrt(var_beta/N)

    return ci_minus, ci_plus


def betaCI_Ridge(z_real, beta, X, l):
    """
    Compute a 90% confidence interval for the beta coefficients - Ridge
    """

    # Calculate variance squared in the error
    z_hat = X.dot(beta)
    N, P = np.shape(X)
    sigma_2 = (np.sum(np.power((z_real-z_hat), 2)))/N

    # Calculate the variance squared of the beta coefficients
    XTX= X.T.dot(X)
    R, R = np.shape(XTX)
    var_beta = np.diag(sigma_2*np.linalg.inv((XTX + l*np.identity(R))))

    # The square root of var_beta is the standard error. Use it to calculate confidence intervals
    ci_minus = beta - 1.645*np.sqrt(var_beta/N)
    ci_plus = beta + 1.645*np.sqrt(var_beta/N)

    return ci_minus, ci_plus

def plotFrankes(x_, y_, z_):
    """
    Plot Franke's function
    """

    fig = plt.figure()
    ax = fig.gca(projection='3d')

    surf = ax.plot_surface(x_, y_, z_, cmap=cm.coolwarm,
                       linewidth=0, antialiased=False)

    # Customize the z axis.
    ax.set_zlim(-0.10, 1.40)
    ax.zaxis.set_major_locator(LinearLocator(10))
    ax.zaxis.set_major_formatter(FormatStrFormatter('%.02f'))


    ax.set_xlabel('X')
    ax.set_ylabel('Y')
    ax.set_zlabel('Z - Franke')

    # Add a color bar which maps values to colors.
    clb = fig.colorbar(surf, shrink=0.5, aspect=5)
    clb.ax.set_title('Level')

    plt.savefig('./Figure/Franke.pdf')

#Ordinary Least Squared function
def ols(x, y, z, degree = 5):
    #x: vector of size(n, 1)
    #y: vector of size(n,1)
    #z: vector of size(n,1)
    xyb_ = np.c_[x, y]
    poly = PolynomialFeatures(degree)
    xyb = poly.fit_transform(xyb_)
    beta = np.linalg.inv(xyb.T.dot(xyb)).dot(xyb.T).dot(z)

    return beta

def RidgeRegression(x, y, z, degree=5, l=0.0001):
    """
    :param x: numpy vector of size (n, 1)
    :param y: numpy vector of size (n, 1)
    :param degree: degree of polynomial fit
    :param l: Ridge penalty coefficient
    :return: numpy array with the beta coefficients
    """
    # Calculate matrix with x, y - polynomials
    M_ = np.c_[x, y]
    poly = PolynomialFeatures(degree)
    M = poly.fit_transform(M_)

    # Calculate beta
    A = np.arange(1, degree + 2)
    rows = np.sum(A)
    beta = (np.linalg.inv(M.T.dot(M) + l * np.identity(rows))).dot(M.T).dot(z)

    return beta

def bootstrap(x, y, z, p_degree, method, n_bootstrap=100):
    # Randomly shuffle data
    data_set = np.c_[x, y, z]
    np.random.shuffle(data_set)
    set_size = round(len(x)/5)

    # Extract test-set, never used in training. About 1/5 of total data
    x_test = data_set[0:set_size, 0]
    y_test = data_set[0:set_size, 1]
    z_test = data_set[0:set_size, 2]
    test_indices = np.linspace(0, set_size-1, set_size)

    # And define the training set as the rest of the data
    x_train = np.delete(data_set[:, 0], test_indices)
    y_train = np.delete(data_set[:, 1], test_indices)
    z_train = np.delete(data_set[:, 2], test_indices)

    Z_predict = []

    MSE = []
    R2s = []
    for i in range(n_bootstrap):
        x_, y_, z_ = resample(x_train, y_train, z_train)

        if method == 'Ridge':
            # Ridge regression, save beta values
            beta = RidgeRegression(x_, y_, z_, degree=p_degree)
        elif method == 'Lasso':
            beta = Lasso(x_, y_, z_, degree=p_degree)
        elif method == 'OLS':
            beta = ols(x_, y_, z_, degree=p_degree)
        else:
            print('ERROR: Cannot recognize method')
            return 0

        M_ = np.c_[x_test, y_test]
        poly = PolynomialFeatures(p_degree)
        M = poly.fit_transform(M_)
        z_hat = M.dot(beta)

        Z_predict.append(z_hat)

        # Calculate MSE
        MSE.append(np.mean((z_test - z_hat)**2))
        R2s.append(R2(z_test, z_hat))
        print('Round: ', i)

    # Calculate MSE, Bias and Variance
    MSE_M = np.mean(MSE)
    R2_M = np.mean(R2s)
    bias = np.mean((z_test - np.mean(Z_predict, axis=0, keepdims=True))**2)
    variance = np.mean(np.var(Z_predict, axis=0, keepdims=True))
    return MSE_M, R2_M, bias, variance

# %%
from AnalysisFunctions import *
import numpy as np
from sklearn.preprocessing import PolynomialFeatures
import matplotlib.pyplot as plt

"""
Analysis of a Ridge Regression model of Franke's function, using set of 1000 random x and y points
"""
# Load random data, 1000 points
X = np.load('data.npy')
x = X[:, 0]
y = X[:, 1]

# Calculate Franke's function without noise
z = FrankeFunction(x, y)

# Study dependence on lambdas
lambdas = [10**-7, 10**-6, 10**-5, 10**-4, 10**-3, 10**-2, 10**-1, 1]
lambdas_log = [-7, -6, -5, -4, -3, -2, -1, 0]

text_file = open("./Results/Bootstrap_ridge.txt", "w")
text_file.write('Investigate lambdas \n')
Bs = []
for la in lambdas:
    Bs.append(RidgeRegression(x, y, z, l=la))

# Generate test data
x_test = np.random.rand(200)
y_test = np.random.rand(200)
z_test = FrankeFunction(x_test, y_test)

# Calculate MSE, R2scores
M_ = np.c_[x_test, y_test]
poly5 = PolynomialFeatures(5)
M = poly5.fit_transform(M_)

MSEs = []
R2s = []
for i in range(len(lambdas)):
    z_predict = M.dot(Bs[i])
    MSE = MeanSquaredError(z_test, z_predict)
    MSEs.append(MSE)
    R2_score = R2(z_test, z_predict)
    R2s.append(R2_score)
    text_file.write('--- Lambda value: {0} ---\n Mean Squared error: {1:.7f} \n R2 Score: {2:.7f}\n'.format(lambdas[i], MSE, R2_score))

#plot
fig, ax1 = plt.subplots()
ax1.plot(lambdas_log, MSEs, 'bo-')
ax1.set_xlabel('Logarithmic lambda')
ax1.set_ylabel('MSE', color='b')
ax1.tick_params('y', colors='b')

ax2 = ax1.twinx()
ax2.plot(lambdas_log, R2s, 'r*-')
ax2.set_ylabel('R2 score', color='r')
ax2.tick_params('y', colors='r')

plt.title('Influence of lambda on MSE and R2 Score')
fig.tight_layout()
plt.savefig('./Results/MSE_R2_lambda.pdf')

# consider how the strength of noise affects the lambda values
noise = np.arange(0.001, 0.4, 0.005)
lambdas = [10**-5, 10**-4, 10**-3]
Bs = []

# Generate more data to test
x_test = np.random.rand(200)
y_test = np.random.rand(200)
M_ = np.c_[x_test, y_test]
poly5 = PolynomialFeatures(5)
M = poly5.fit_transform(M_)

for la in lambdas:
    B = []
    for n in noise:
        z = FrankeFunction(x, y, noise=n)
        B.append(RidgeRegression(x, y, z, l=la))
    Bs.append(B)

lines = []
plt.figure()
for i in range(len(lambdas)):
    text_file.write('--- lambda value:{}---'.format(lambdas[i]))
    line = []
    for j in range(len(noise)):
        z_test = FrankeFunction(x_test, y_test, noise=noise[j])
        z_predict = M.dot(Bs[i][j])
        MSE = MeanSquaredError(z_test, z_predict)
        line.append(MSE)
        R2_score = R2(z_test, z_predict)
        text_file.write(' Noise: {0} \n Mean Squared error: {1:.7f} \n R2 Score: {2:.7f}\n'.format(noise[j], MSE, R2_score))
    plt.plot(noise, line, label='Lambda = {0}'.format(lambdas[i]))

plt.legend()
plt.xlabel('Degree of noise')
plt.ylabel('MSE')
plt.title('Influence of lambda and noise on MSE')
plt.savefig('./Results/lambda_noise_MSE.pdf')

#confidence interval

# Generate test data
x_test1 = np.random.rand(1000)
y_test1 = np.random.rand(1000)
z_test1 = FrankeFunction(x_test1, y_test1)

# Calculate beta values and polynomial matrix
beta = RidgeRegression(x, y, z, degree=5, l=10**-4)
M_ = np.c_[x_test1, y_test1]
poly5 = PolynomialFeatures(5)
M = poly5.fit_transform(M_)

# Calculate beta confidence intervals
conf1, conf2 = betaCI_Ridge(z_test1, beta, M, l=10**-4)

for i in range(len(conf1)):
    text_file.write('Beta {0}: {1:5f} & [{2:5f}, {3:5f}]'.format(i, beta[i], conf1[i], conf2[i]))

# Use bootstrap algorithm to estimate MSE, R2, bias and variance
MSE_b, R2_b, bias_b, variance_b = bootstrap(x, y, z, method='Ridge', p_degree=5)
text_file.write('--- BOOTSTRAP for Ridge --- \n')
text_file.write('MSE: {} \n'.format(MSE_b))
text_file.write('R2: {} \n'.format(R2_b))
text_file.write('Bias: {} \n'.format(bias_b))
text_file.write('Variance: {} \n'.format(variance_b))
text_file.close()
# Out:
# C:\Users\bod\anaconda3\lib\site-packages\ipykernel_launcher.py:153: DeprecationWarning: using a non-integer array as obj in delete will result in an error in the future
# C:\Users\bod\anaconda3\lib\site-packages\ipykernel_launcher.py:154: DeprecationWarning: using a non-integer array as obj in delete will result in an error in the future
# C:\Users\bod\anaconda3\lib\site-packages\ipykernel_launcher.py:155: DeprecationWarning: using a non-integer array as obj in delete will result in an error in the future
# Round:  0
# Round:  1
# Round:  2
# Round:  3
# Round:  4
# Round:  5
# Round:  6
# Round:  7
# Round:  8
# Round:  9
# Round:  10
# Round:  11
# Round:  12
# Round:  13
# Round:  14
# Round:  15
# Round:  16
# Round:  17
# Round:  18
# Round:  19
# Round:  20
# Round:  21
# Round:  22
# Round:  23
# Round:  24
# Round:  25
# Round:  26
# Round:  27
# Round:  28
# Round:  29
# Round:  30
# Round:  31
# Round:  32
# Round:  33
# Round:  34
# Round:  35
# Round:  36
# Round:  37
# Round:  38
# Round:  39
# Round:  40
# Round:  41
# Round:  42
# Round:  43
# Round:  44
# Round:  45
# Round:  46
# Round:  47
# Round:  48
# Round:  49
# Round:  50
# Round:  51
# Round:  52
# Round:  53
# Round:  54
# Round:  55
# Round:  56
# Round:  57
# Round:  58
# Round:  59
# Round:  60
# Round:  61
# Round:  62
# Round:  63
# Round:  64
# Round:  65
# Round:  66
# Round:  67
# Round:  68
# Round:  69
# Round:  70
# Round:  71
# Round:  72
# Round:  73
# Round:  74
# Round:  75
# Round:  76
# Round:  77
# Round:  78
# Round:  79
# Round:  80
# Round:  81
# Round:  82
# Round:  83
# Round:  84
# Round:  85
# Round:  86
# Round:  87
# Round:  88
# Round:  89
# Round:  90
# Round:  91
# Round:  92
# Round:  93
# Round:  94
# Round:  95
# Round:  96
# Round:  97
# Round:  98
# Round:  99
